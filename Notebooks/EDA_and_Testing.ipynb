# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/yashw/home_price_predictor/data/hyderabad_real_estate_dataset3.csv")

# %%
data.head()
# Out:
#   Property_ID Transaction_Date  Transaction_Year  Transaction_Month  \
# 0  HYD_000001       2024-05-05              2024                  5
# 1  HYD_000002       2018-07-10              2018                  7
# 2  HYD_000003       2024-07-14              2024                  7
# 3  HYD_000004       2022-08-04              2022                  8
# 4  HYD_000005       2019-10-02              2019                 10
#
#        Market_Condition Location_Name Location_Maturity  Area_SqFt  Bedrooms  \
# 0         Stabilization      Begumpet       established       1398         3
# 1   RERA Implementation      Begumpet       established       1717         4
# 2         Stabilization  Secunderabad       established       3188         4
# 3       Post-COVID Boom    Kukatpally       established       2713         5
# 4  Market Consolidation    Somajiguda       established       1382         2
#
#    Bathrooms  ... IT_Hub_Proximity_Km  Metro_Proximity_Km  Amenities_Score  \
# ...

# %%
data.columns
# Out:
# Index(['Property_ID', 'Transaction_Date', 'Transaction_Year',
#        'Transaction_Month', 'Market_Condition', 'Location_Name',
#        'Location_Maturity', 'Area_SqFt', 'Bedrooms', 'Bathrooms',
#        'Property_Type', 'Resale', 'New_Construction', 'Gated_Community',
#        'Builder_Reputation', 'Year_Built', 'Possession_Status',
#        'Facing_Direction', 'Balcony', 'Maintenance_Staff', 'Gymnasium',
#        'Swimming_Pool', 'Landscaped_Gardens', 'Jogging_Track', 'Club_House',
#        '24x7_Security', 'Power_Backup', 'Car_Parking', 'Lift_Available',
#        'School_Proximity_Km', 'Hospital_Proximity_Km', 'IT_Hub_Proximity_Km',
#        'Metro_Proximity_Km', 'Amenities_Score', 'Furnishing_Status',
#        'Transaction_Type', 'Floors', 'Age_of_Property_Years', 'Price_per_SqFt',
#        'Price_Lakhs', 'Period'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Property_ID            10000 non-null  object
#  1   Transaction_Date       10000 non-null  object
#  2   Transaction_Year       10000 non-null  int64
#  3   Transaction_Month      10000 non-null  int64
#  4   Market_Condition       10000 non-null  object
#  5   Location_Name          10000 non-null  object
#  6   Location_Maturity      10000 non-null  object
#  7   Area_SqFt              10000 non-null  int64
#  8   Bedrooms               10000 non-null  int64
#  9   Bathrooms              10000 non-null  int64
#  10  Property_Type          10000 non-null  object
#  11  Resale                 10000 non-null  int64
#  12  New_Construction       10000 non-null  int64
#  13  Gated_Community        10000 non-null  int64
# ...

# %%
print(type(data["Location_Name"].value_counts()))
# Out:
# <class 'pandas.core.series.Series'>

# %%
y=data["Location_Name"].value_counts()

# %%
for i in y.index:
    print(i)
# Out:
# Kukatpally
# Miyapur
# Nallagandla
# Narsingi
# Uppal
# Punjagutta
# Kollur
# Rajendranagar
# Nizampet
# Begumpet
# Attapur
# Somajiguda
# Patancheru
# LB Nagar
# Bachupally
# Hitech City
# Rampally
# Mehdipatnam
# Banjara Hills
# Kompally
# Gachibowli
# Pocharam
# Ameerpet
# Tolichowki
# Kondapur
# Secunderabad
# Jubilee Hills
# Shamshabad
# Manikonda
# Madhapur
